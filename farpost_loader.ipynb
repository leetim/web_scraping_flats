# %% [markdown]
# **Author:** Волокжанин Вадим Юрьевич<br>
# **Create date:** 26.08.2019<br>
# **Description:** Загрузка данных по квартирам с FarPost

# %% [markdown]
# # Импортруем необходимые модули

# %%
# Для мониторинга выполнения циклов
from tqdm import tqdm_notebook, tqdm

# Обработка HTML 
from bs4 import BeautifulSoup
# Для генерации поддельного User agent
from fake_useragent import UserAgent
# Для работы с HTTP-запросами 
from requests import ConnectTimeout, ConnectionError 
from requests.exceptions import ProxyError

# Для работы с табличными данными
import pandas as pd

# Для работы с регулярными выражениями 
import re

# Для работы с массивами и вычислениями
import numpy as np 

# Для работы с SQL
from sqlalchemy import create_engine

# Для работы с операционной системой
import os

# Для работы с циклами
from itertools import cycle

# Для работы с математическими вычислениями
import math

# %%
# Создадим подключние к dwh
engine = create_engine('postgres://volokzhanin:{password}@localhost:5432/volokzhanin'.format(password = os.getenv('PASSWORD1', False)))

# %% [markdown]
# # Создадим функции и наборы данных

# %%
def get_my(url, headers, proxies, session, timeout = 50):
    """
    Функция для возвращения ссессии пользователя с заходом на url. 
    Параметры: url - строка url, headers - заголовки, proxies - прокси сервер, session - сессия пользователя. 
    Выход - сессия пользователя с заходом на указанную страницу. 
    """
    return session.get(
        url, 
        headers = headers, 
        proxies = proxies, 
        timeout = timeout
        )

def get_pages(url, headers, proxies, session):  
    """
    Функция для возварщения количества страниц. 
    Параметры: url - url, headers - заголовки, proxies - прокси сервер, session - сессия пользователя. 
    Выход - список с количеством страниц и предложений.
    """    
    url_offers = get_my(url, headers, proxies, session)
    bsObj_offers = BeautifulSoup(url_offers.text, 'html.parser')
    count_offers = bsObj_offers.find("span", { "class" : "item itemsCount" }).text
    pages = math.ceil(int(re.sub('\D', '', count_offers))/50)
    return [int(re.sub('\D', '', count_offers)), pages]

def get_pages_all(url = 'https://www.farpost.ru/vladivostok/realty/sell_flats'):
    """
    Функция для возварщения количества страниц. 
    Параметры: нет. 
    Выход - список с количеством страниц и предложений.
    """ 
    
    # Получаем общее количество предложений и страниц
    while True: 
        try:  
            headers = {'User-Agent' : UserAgent().chrome}
            proxies = {'https' : 'https://' + next(proxy_cycle)}
            session = requests.Session()
            adapter = requests.adapters.HTTPAdapter(max_retries = 1)
            session.mount('https://', adapter)
            offers, pages = get_pages(
                url, 
                headers = headers, 
                proxies = proxies, 
                session = session
            )
            break
        except ConnectTimeout: 
            continue
    return[offers, pages]

def get_link_offers(url, page, proxies, headers, session): 
    """
    Функция для получения ссылок на предложения Farpost
    Параметры: url - путь с запросом, page - страница, headers - заголовки, proxies - прокси сервер, session - сессия пользователя.  
    Выход: result_df - таблица с предложениями на выбранной странице
    """
    # Перейдем на страницу  и укажем прокси-сервера
    url_links = get_my(
        url, 
        proxies = proxies, 
        headers = headers,
        session = session   
    )

    # Приведем текст к понятному виду BeautifulSoup
    bsObj_offers = BeautifulSoup(url_links.text, 'html5lib')

    # Определим маску поиска ссылки
    regex = re.compile('/vladivostok/realty/sell_flats/.+\d{5,10}.html')
    links = bsObj_offers.find_all("a")

    # Создадим объект для сбора результата 
    links_list = []

    # Обойдем циклом все ссылки и оставим только необходимые
    for j in links:        
        current_link = j.get('href')  
        if current_link is None:
            continue
        elif regex.match(current_link) is None: 
            continue      
        else: 
            link = regex.match(current_link)            
            links_list.append(link.string)   
            
    # Оставим только уникальные ссылки
    result_df = pd.DataFrame({'raw_url' : links_list})
    result_df.drop_duplicates(
        keep = 'first',
        inplace = True
    )
    
    # Обработаем данные 
    result_df['url'] = result_df.apply(lambda x: 'https://www.farpost.ru' + x['raw_url'], axis = 1)
    result_df['page'] = url
    return result_df

def get_bypass_df_all(pages, url = 'https://www.farpost.ru/vladivostok/realty/sell_flats'): 
    """
    Функция для получения таблицы обхода farpost. 
    Вход: количество страниц. 
    Выход: таблица для обхода.
    """
    while True: 
        try:  
            headers = {'User-Agent' : UserAgent().chrome}
            proxies = {'https' : 'https://' + next(proxy_cycle)}
            session = requests.Session()
            adapter = requests.adapters.HTTPAdapter(max_retries = 5)
            session.mount('https://', adapter)
            # Создаем объект для сбора результата 
            bypass_df = pd.DataFrame()

            # Пройдемся циклом по всем страницам запроса и соберем все ссылки
            for page in range(1, pages + 1):
                current_url = url + '/?page={page}'.format(
                    page = page
                )
                current_table = get_link_offers(
                    url = current_url, 
                    proxies  = proxies, 
                    headers = headers, 
                    session = session,
                    page = page
                )    
                bypass_df = pd.concat([bypass_df, current_table])
            break
        except ConnectTimeout: 
            continue

    bypass_df.reset_index(drop = True, inplace = True)
    return bypass_df

def clean_ad(text): 
    """
    Функция для очистки текста объявления. 
    Вход: сырой текст. 
    Выход: очищенный тескст. 
    """
    tamplate = re.compile('\n|\t| во Владивостоке|Подробности о доме|Адрес|Этаж')
    clean_text = ' '.join(tamplate.sub(' ', text).split()).strip()
    return clean_text

def address_ad(text_block): 
    """
    Функция для получения адреса объявления. 
    Вход: текст для извлечения адреса.
    Выход: адрес объявления.  
    """
    raw_address = re.findall('Адрес[\t\n\r]+.+', text_block)
    if len(raw_address) > 0: 
        address = 'Приморский край, Владивосток, ' + clean_ad(raw_address[0])
    else: 
        address = None
    return address

def title_ad(bsObj_object): 
    """
    Функция для получения заголовка объявления. 
    Вход: beautiful soup объект.
    Выход: заголовок объявления.  
    """
    title = bsObj_object.find('h1', {'class' : 'subject viewbull-field__container'}).text
    title = clean_ad(title)
    return title

def image_ad(bsObj_object): 
    """
    Функция для получения изображений объявления. 
    Вход: beautiful soup объект.
    Выход: лист изображений объявления.  
    """
    image = bsObj_object.find_all('img')
    if len(image) > 0:
        image_list = []
        for im in image: 
            current_image = re.findall(r'v/\d{1,100}_bulletin', str(im))
            if len(current_image) > 0: 
                image_list.append('https://static.baza.farpost.ru/' + current_image[0])
    else: 
        image_list = None
    return image_list

def price_ad(bsObj_object): 
    """
    Функция для получения цены в объявлении. 
    Вход: beautiful soup объект.
    Выход: цена в объявлении.  
    """
    price = bsObj_object.find_all('span', {'class' : 'viewbull-summary-price__value'})
    if len(price) > 0: 
            price = price[0].text
            price = int(re.sub('₽|\s', '', price))
    else: 
        price = None
    return price

def status_house_ad(text_block): 
    """
    Функция для получения статуса дома. 
    Вход: текст для извлечения статуса дома.
    Выход: статуса дома.    
    """
    is_house_delivered = re.findall('Этап строительства дома[\t\n\r]+Не сдан', text_block)
    if len(is_house_delivered) > 0:
        is_house_delivered = 0
    else: 
        is_house_delivered = 1    
    return is_house_delivered

def area_ad(text_block): 
    """
    Функция для получения площади в объявлении. 
    Вход: текст для извлечения площади в объявлении.
    Выход: площадь в объявления.   
    """
    area = re.findall('Площадь по документам[\t\n\r]+.+', text_block)
    if len(area) > 0: 
        area = int(re.findall(r'\d{1,4}', area[0])[0])
    else: 
        area = None
    return area

def is_mortage_ad(bsObj_object): 
    """
    Функция для получения статуса ипотеки в объявлении. 
    Вход: текст для извлечения статуса ипотеки в объявлении.
    Выход: статуса ипотеки в объявлении.   
    """
    is_mortage = re.findall('Подходит под ипотеку', text_block)
    if len(is_mortage) > 0: 
        is_mortage = 1
    else: 
        is_mortage = 0
    return is_mortage

def floor_ad(text_block): 
    """
    Функция для получения этажа в объявления. 
    Вход: текст для извлечения этажа в объявлении..
    Выход: этаж в объявления.  
    """
    floor = re.findall('Этаж[\t\n\r]+.+', text_block)
    if len(floor) > 0: 
        floor = clean_ad(floor[0])
    else: 
        floor = None
    return floor

# %% [markdown]
# # Соберем прокси-сервера

# %%
# Получаем и записываем таблицу с proxy
# os.chdir('/mnt/sdb1/Documents/Projects/web_scraping_flats/sripts')
# import proxy_loader

# proxy_loader = proxy_loader.proxy_loader() 
# proxy_df = proxy_loader.write_check_proxy()
# proxy_df.head()

# %%
proxy_df = pd.read_sql(
    con = engine,
    sql = """
    select 
            name 
    from 
            staging_tables.proxy_servers
    where 
            is_work = True
    """
)

# Создадим зацикливавние по прокси серверам
proxy_cycle = cycle(proxy_df.name)

proxy_df.head()
# Out:
#                    name
# 0   212.95.180.50:53281
# 1     62.122.18.7:49693
# 2  91.225.109.186:56617
# 3     73.55.10.186:8080
# 4   23.237.173.102:3128

# %% [markdown]
# # Получаем даные предложений

# %%
# Получим количество страниц и предложений 
offers, pages = get_pages_all()
print(offers, pages)
# Out:
# 3599 72

# %% [markdown]
# # Создаем таблицу обхода

# %%
bypass_df = get_bypass_df_all(pages)
bypass_df.head()
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4d63b00>, 'Connection to 72.21.66.222 timed out. (connect timeout=10)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.farpost.ru', port=443): Read timed out. (read timeout=10)",)': /vladivostok/realty/sell_flats/?page=5
#                                              raw_url  \
# 0  /vladivostok/realty/sell_flats/2-komnatnaja-kv...
# 1  /vladivostok/realty/sell_flats/prodazha-smart-...
# 2  /vladivostok/realty/sell_flats/2-komnatnaja-kv...
# 3  /vladivostok/realty/sell_flats/3-komnatnaja-kv...
# 4  /vladivostok/realty/sell_flats/kvartiry-v-zhil...
#
#                                                  url  \
# 0  https://www.farpost.ru/vladivostok/realty/sell...
# 1  https://www.farpost.ru/vladivostok/realty/sell...
# 2  https://www.farpost.ru/vladivostok/realty/sell...
# 3  https://www.farpost.ru/vladivostok/realty/sell...
# 4  https://www.farpost.ru/vladivostok/realty/sell...
#
#                                                 page
# 0  https://www.farpost.ru/vladivostok/realty/sell...
# 1  https://www.farpost.ru/vladivostok/realty/sell...
# 2  https://www.farpost.ru/vladivostok/realty/sell...
# 3  https://www.farpost.ru/vladivostok/realty/sell...
# 4  https://www.farpost.ru/vladivostok/realty/sell...

# %% [markdown]
# # Собираем все объявления

# %%
result_df = pd.DataFrame()
for url in bypass_df.url[:100]:
    current_bypass_df = bypass_df[bypass_df.url == url]
    current_bypass_df.reset_index(drop = True, inplace = True)
    # Получаем таблицу обхода
    while True: 
        try:
            headers = {'User-Agent' : UserAgent().chrome}
            proxies = {'https' : 'https://' + next(proxy_cycle)}
            session = requests.Session()
            adapter = requests.adapters.HTTPAdapter(max_retries = 1)
            session.mount('https://', adapter)
            get_my(
                url = current_table.page[0], 
                proxies = proxies, 
                headers = headers,
                session = session,
                timeout = 5
            )
            offers_current = get_my(
                url = current_bypass_df.url[0], 
                proxies = proxies, 
                headers = headers,
                session = session  
            )

            bsObj_object = BeautifulSoup(offers_current.text, 'html5lib')
            # Пишем условие, если блокируют
            if len(re.findall('Из вашей подсети наблюдается подозрительная активность. Поставьте отметку, чтобы продолжить.', bsObj_object.text)) > 0:
                continue
            else:
                title = title_ad(bsObj_object)
                image = image_ad(bsObj_object)
                price = price_ad(bsObj_object)
                text_block = bsObj_object.find_all('div',{'id' : 'fieldsetView'})
                if len(text_block) > 0: 
                    text_block =  text_block[0].text
                    address = address_ad(text_block)
                    status_house = status_house_ad(text_block)
                    area = area_ad(text_block)
                    is_mortage = is_mortage_ad(text_block)
                    floor = floor_ad(text_block)
                current_df = pd.DataFrame({'title' : [title], 'image' : [image], 'address' : [address], 'status_house' : [status_house], 'price' : [price], 'area' : [area], 
                                           'is_mortage' : [is_mortage], 'floor' : [floor], 'url' : [current_bypass_df.url[0]], 'source' : ['farpost']})
                result_df = pd.concat([result_df, current_df])
            break
        except (ConnectTimeout, ProxyError, ConnectionError): 
            continue    
result_df.reset_index(drop = True, inplace = True)
result_df.head()
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b63bc048>, 'Connection to 191.102.94.138 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4b73518>, 'Connection to 35.247.250.167 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4b73160>, 'Connection to 191.102.70.18 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b42ebb00>, 'Connection to 193.117.138.126 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b53d2a90>, 'Connection to 75.151.213.85 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b491c080>, 'Connection to 18.130.236.116 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4937588>, 'Connection to 47.254.132.82 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b5a647f0>, 'Connection to 67.154.191.166 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b45c3f28>, 'Connection to 195.189.71.187 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b41c4cc0>, 'Connection to 213.59.251.247 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b5189780>, 'Connection to 35.247.250.167 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4d49630>, 'Connection to 115.124.75.77 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4d55f28>, 'Connection to 177.46.149.22 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4fb8f60>, 'Connection to 165.22.91.6 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b49e3160>, 'Connection to 165.22.91.6 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b47b9e48>, 'Connection to 37.60.35.1 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer'))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b507f0f0>, 'Connection to 165.22.91.6 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4a0cba8>, 'Connection to 187.243.253.182 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b45c3320>, 'Connection to 192.140.91.133 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b51ed2e8>, 'Connection to 178.77.197.96 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b5350e10>, 'Connection to 191.7.194.165 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b43e6470>, 'Connection to 37.60.35.1 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b5897c88>, 'Connection to 213.172.158.39 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b6669400>, 'Connection to 192.227.237.110 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4388860>, 'Connection to 24.172.225.122 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b41602b0>, 'Connection to 200.205.21.66 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', OSError('Tunnel connection failed: 502 Bad Gateway',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4794710>, 'Connection to 103.254.126.182 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4d64080>, 'Connection to 171.100.29.202 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4105438>, 'Connection to 103.9.188.160 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4ad35f8>, 'Connection to 4.34.50.189 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b420b2b0>, 'Connection to 191.102.94.138 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b420bf98>, 'Connection to 137.59.163.50 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b420b6d8>, 'Connection to 114.110.22.90 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4413ba8>, 'Connection to 18.130.236.116 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b46dada0>, 'Connection to 41.79.67.1 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4a93940>, 'Connection to 109.75.140.158 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b46dacf8>, 'Connection to 35.247.250.167 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b01d4b00>, 'Connection to 190.122.97.138 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b47945f8>, 'Connection to 193.117.138.126 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b01c4e80>, 'Connection to 89.121.211.242 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b01cbfd0>, 'Connection to 46.20.59.243 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b01c45c0>, 'Connection to 191.102.94.138 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b01d4748>, 'Connection to 38.134.10.106 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b01d4c50>, 'Connection to 162.248.247.153 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b01f0b00>, 'Connection to 101.109.143.71 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4cf3e10>, 'Connection to 118.173.232.5 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b5897748>, 'Connection to 92.249.122.108 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b64d55f8>, 'Connection to 160.2.52.234 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b01f0240>: Failed to establish a new connection: [Errno 111] Connection refused',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b5d15048>, 'Connection to 118.173.232.5 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b658feb8>, 'Connection to 187.243.253.182 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4395b00>, 'Connection to 181.112.188.38 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer'))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4efb550>, 'Connection to 36.89.193.73 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4c793c8>, 'Connection to 75.146.218.153 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b55d4828>, 'Connection to 101.109.143.71 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4162a58>, 'Connection to 38.134.10.106 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b40c6c18>, 'Connection to 27.68.135.14 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b416dc18>, 'Connection to 192.99.207.23 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4217710>, 'Connection to 50.247.207.5 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4162d30>, 'Connection to 160.218.116.34 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', timeout('timed out',))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', ConnectionResetError(104, 'Connection reset by peer'))': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4e9dc88>, 'Connection to 176.192.8.6 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4eb3278>, 'Connection to 64.17.30.238 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f90b4eb3d68>, 'Connection to 103.9.188.160 timed out. (connect timeout=5)')': /vladivostok/realty/sell_flats/?page=1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-339-d54ff3033331> in <module>
#      30                 continue
#      31             else:
# ---> 32                 title = title_ad(bsObj_object)
#      33                 image = image_ad(bsObj_object)
#      34                 price = price_ad(bsObj_object)
#
# <ipython-input-336-b4d866f36ff9> in title_ad(bsObj_object)
#     162     Выход: заголовок объявления.
#     163     """
# --> 164     title = bsObj_object.find('h1', {'class' : 'subject viewbull-field__container'}).text
#     165     title = clean_ad(title)
#     166     return title
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Переработать
def get_text_ad(bsObj_object): 
    """
    Функция для получения текст объявления. 
    Вход: текст для извлечения адреса.
    Выход: адрес объявления.   
    """
    text = bsObj_object.find('p', {'class' : 'inplace mod__label_up_down auto-shy'}).text
    text = clean_ad(text)
    return title
# текст

# %%
# bsObj_object.text

# %%
#

# %%
# %who_ls function
# %who_ls

# %%
# pd.options.display.html.table_schema = True
# pd.options.display.max_rows = None
# bypass_df
